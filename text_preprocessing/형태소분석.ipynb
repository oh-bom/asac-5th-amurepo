# %%
import pandas as pd

df1 = pd.read_csv('review_combined.csv', encoding = 'utf-8')
df2 = pd.read_csv('review_pykospacing.csv', encoding = 'utf-8')
del df1['Unnamed: 0']
del df2['Unnamed: 0']
df1.head()
# Out:
#         제품코드   리뷰유형    레벨      회원아이디        리뷰날짜               회원스팩 사이즈   별점  \
# 0  2272830.0  style  LV.5       류신사류  2022.02.27  남성 · 173cm · 72kg   [  5.0
# 1  2272830.0  style  LV.4       썰린당근  2022.03.04  여성 · 167cm · 50kg   [  5.0
# 2  2272830.0  style  LV.3  Choichita  2023.02.26  여성 · 166cm · 48kg   [  5.0
# 3  2272830.0  style  LV.5     트월king  2022.03.28  남성 · 176cm · 71kg   [  5.0
# 4  2272830.0  style  LV.5      lacos  2022.03.06  여성 · 164cm · 55kg   [  5.0
#
#                                                 리뷰내용
# 0  시티보이 필수템이라 좋아요 근데 시티보이룩은 처음이라 사이즈감 모르고 모델임 따라 ...
# 1                        베리굿입니다 크게 입는걸 좋아해서 너무 만족합니다
# 2  깔끔하고 깨끗해서 마음에 들어요. 색감 자체도 너무 밝지 않고 어둡지 않아서 아무 ...
# 3               조금 사진이 너드같긴하지만 실제로는 얼굴만 너드고 옷은 멀쩡합니다
# 4               색감도 예쁘고 사이즈도 딱 예쁘게 맞습니다. 기본템으로 추천합니다

# %%
df1 = df1[df1.제품코드 != 2272830]
df1 = df1[df1.제품코드 != 3080482]

# %%
df1.duplicated().sum()
# Out:
# 373

# %%
df1 = df1.drop_duplicates()
df1.reset_index(drop = True, inplace = True)
df1.head()
# Out:
#        제품코드   리뷰유형    레벨        회원아이디        리뷰날짜               회원스팩 사이즈   별점  \
# 0  994588.0  style  LV.5      선한주황주얼리  2023.04.14  남성 · 183cm · 73kg   L  5.0
# 1  994588.0  style  LV.6        감자여섯개  2020.06.03                NaN   M  3.0
# 2  994588.0  style   NaN          NaN  2021.02.12  여성 · 158cm · 40kg   M  5.0
# 3  994588.0  style  LV.6          고찌리  2022.07.14                NaN   M  5.0
# 4  994588.0  style  LV.5  @caesarceas  2023.06.25  남성 · 174cm · 60kg   M  5.0
#
#                                                 리뷰내용
# 0                   처음에는 너무 오버핏이라 걱정했는데 막상 입어보니 이쁘네요
# 1                  무신사에서 좋은 가격에 잘 산거 같아요 오래 쓸 것 같습니다
# 2  생각보다 많이 얇고 주름이 잘 생기는 셔츠에여 근데 핏이 사기라 그냥 사는 걸 추천...
# 3                   엠사이즈가 딱 좋은듯해요 네이비색도 하나 살가 생각중이에오
# 4               옥스포드로 구매했어요시티보이/캐주얼로 입으려 샀는데 찰떡콩떡이네요

# %%
df2.head()
# Out:
#                                           pre_review
# 0                  처음에는 너무 오버핏이라 걱정했는데 막상 입어보니 이 쁘네요
# 1                무신사에서 좋은 가격에 잘 산 거 같아 요 오래 쓸 것 같습니다
# 2  생각보다 많이 얇고 주름이 잘 생기는 셔츠에 여 근데 핏이 사기라 그냥 사는 걸 추...
# 3              엠사이즈가 딱 좋은 듯해요 네이비 색도 하나 살가 생각 중 이에 오
# 4             옥스포드로 구매했어요시티보이/ 캐주얼로 입으려 샀는데 찰떡 콩떡이네요

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827445 entries, 0 to 827444
# Data columns (total 9 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   제품코드    827445 non-null  float64
#  1   리뷰유형    827445 non-null  object
#  2   레벨      802257 non-null  object
#  3   회원아이디   802257 non-null  object
#  4   리뷰날짜    827445 non-null  object
#  5   회원스팩    548620 non-null  object
#  6   사이즈     762499 non-null  object
#  7   별점      827445 non-null  float64
#  8   리뷰내용    827445 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 56.8+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827446 entries, 0 to 827445
# Data columns (total 1 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   pre_review  827445 non-null  object
# dtypes: object(1)
# memory usage: 6.3+ MB

# %%
df2.isnull().sum()
# Out:
# pre_review    1
# dtype: int64

# %%
df2.head()
# Out:
#                                           pre_review
# 0                  처음에는 너무 오버핏이라 걱정했는데 막상 입어보니 이 쁘네요
# 1                무신사에서 좋은 가격에 잘 산 거 같아 요 오래 쓸 것 같습니다
# 2  생각보다 많이 얇고 주름이 잘 생기는 셔츠에 여 근데 핏이 사기라 그냥 사는 걸 추...
# 3              엠사이즈가 딱 좋은 듯해요 네이비 색도 하나 살가 생각 중 이에 오
# 4             옥스포드로 구매했어요시티보이/ 캐주얼로 입으려 샀는데 찰떡 콩떡이네요

# %%
df2.dropna(inplace = True)
df2.reset_index(drop = True, inplace = True)
df2.head()
# Out:
#                                           pre_review
# 0                  처음에는 너무 오버핏이라 걱정했는데 막상 입어보니 이 쁘네요
# 1                무신사에서 좋은 가격에 잘 산 거 같아 요 오래 쓸 것 같습니다
# 2  생각보다 많이 얇고 주름이 잘 생기는 셔츠에 여 근데 핏이 사기라 그냥 사는 걸 추...
# 3              엠사이즈가 딱 좋은 듯해요 네이비 색도 하나 살가 생각 중 이에 오
# 4             옥스포드로 구매했어요시티보이/ 캐주얼로 입으려 샀는데 찰떡 콩떡이네요

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827445 entries, 0 to 827444
# Data columns (total 1 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   pre_review  827445 non-null  object
# dtypes: object(1)
# memory usage: 6.3+ MB

# %%
len(df1)
# Out:
# 827445

# %%
len(df2)
# Out:
# 827445

# %%
df1.tail()
# Out:
#              제품코드   리뷰유형    레벨       회원아이디        리뷰날짜               회원스팩 사이즈  \
# 827440  3424255.0  goods  LV.5   Young0.0뀨  2023.08.23  남성 · 176cm · 80kg  XL
# 827441  3397135.0  photo  LV.6          와쥐  2023.08.10  여성 · 164cm · 45kg   S
# 827442  3397135.0  goods  LV.2      복잡한잠실핀       21일 전                NaN   M
# 827443  3397135.0  goods  LV.4  mi_______n  2023.10.15                NaN   M
# 827444  3397135.0  goods  LV.6          와쥐  2023.08.10  여성 · 164cm · 45kg   S
#
#          별점                                        리뷰내용
# 827440  5.0                재질 색상 사이즈 가격 모두 마음에 드네요가성비 굿
# 827441  5.0                   배송이 엄청 빨라서 좋네요 팔부분이 포인트예요
# 827442  5.0  흰색 셔츠 구매하고 싶어는데 사이즈도 넉넉하고 길이도 적당해서 마음에 드네요
# 827443  5.0               옷이 편하고 이뻐요 사이즈도 적당하고 자주 입을것같음
# 827444  5.0              기본템이라 좋아요 막 걸쳐입기 편하고 디자인도 무난해요

# %%
df2.tail()
# Out:
#                                          pre_review
# 827440                재질 색상 사이즈 가격 모두 마음에 드네요가 성비 굿
# 827441                   배송이 엄청 빨라서 좋네요 팔 부분이 포인트예요
# 827442  흰색 셔츠 구매하고 싶어는 데 사이즈도 넉넉하고 길이도 적당해서 마음에 드네요
# 827443             옷이 편하고 이 뻐요 사이즈도 적당하고 자주 입을 것 같음
# 827444              기본템이라 좋아요 막 걸쳐 입기 편하고 디자인도 무난해요

# %%
df = pd.concat([df1, df2], axis = 1)
df.head()
# Out:
#        제품코드   리뷰유형    레벨        회원아이디        리뷰날짜               회원스팩 사이즈   별점  \
# 0  994588.0  style  LV.5      선한주황주얼리  2023.04.14  남성 · 183cm · 73kg   L  5.0
# 1  994588.0  style  LV.6        감자여섯개  2020.06.03                NaN   M  3.0
# 2  994588.0  style   NaN          NaN  2021.02.12  여성 · 158cm · 40kg   M  5.0
# 3  994588.0  style  LV.6          고찌리  2022.07.14                NaN   M  5.0
# 4  994588.0  style  LV.5  @caesarceas  2023.06.25  남성 · 174cm · 60kg   M  5.0
#
#                                                 리뷰내용  \
# 0                   처음에는 너무 오버핏이라 걱정했는데 막상 입어보니 이쁘네요
# 1                  무신사에서 좋은 가격에 잘 산거 같아요 오래 쓸 것 같습니다
# 2  생각보다 많이 얇고 주름이 잘 생기는 셔츠에여 근데 핏이 사기라 그냥 사는 걸 추천...
# 3                   엠사이즈가 딱 좋은듯해요 네이비색도 하나 살가 생각중이에오
# 4               옥스포드로 구매했어요시티보이/캐주얼로 입으려 샀는데 찰떡콩떡이네요
#
#                                           pre_review
# 0                  처음에는 너무 오버핏이라 걱정했는데 막상 입어보니 이 쁘네요
# 1                무신사에서 좋은 가격에 잘 산 거 같아 요 오래 쓸 것 같습니다
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827445 entries, 0 to 827444
# Data columns (total 10 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   제품코드        827445 non-null  float64
#  1   리뷰유형        827445 non-null  object
#  2   레벨          802257 non-null  object
#  3   회원아이디       802257 non-null  object
#  4   리뷰날짜        827445 non-null  object
#  5   회원스팩        548620 non-null  object
#  6   사이즈         762499 non-null  object
#  7   별점          827445 non-null  float64
#  8   리뷰내용        827445 non-null  object
#  9   pre_review  827445 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 63.1+ MB

# %%
df['pre_review'].duplicated().sum()
# Out:
# 141815

# %%
# df = df.drop_duplicates()
# df.reset_index(drop = True, inplace = True)
# df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827445 entries, 0 to 827444
# Data columns (total 10 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   제품코드        827445 non-null  float64
#  1   리뷰유형        827445 non-null  object
#  2   레벨          802257 non-null  object
#  3   회원아이디       802257 non-null  object
#  4   리뷰날짜        827445 non-null  object
#  5   회원스팩        548620 non-null  object
#  6   사이즈         762499 non-null  object
#  7   별점          827445 non-null  float64
#  8   리뷰내용        827445 non-null  object
#  9   pre_review  827445 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 63.1+ MB

# %%
df['pre_review'] = df['pre_review'].str.replace('+', '')
df.head()
# Out:
#        제품코드   리뷰유형    레벨        회원아이디        리뷰날짜               회원스팩 사이즈   별점  \
# 0  994588.0  style  LV.5      선한주황주얼리  2023.04.14  남성 · 183cm · 73kg   L  5.0
# 1  994588.0  style  LV.6        감자여섯개  2020.06.03                NaN   M  3.0
# 2  994588.0  style   NaN          NaN  2021.02.12  여성 · 158cm · 40kg   M  5.0
# 3  994588.0  style  LV.6          고찌리  2022.07.14                NaN   M  5.0
# 4  994588.0  style  LV.5  @caesarceas  2023.06.25  남성 · 174cm · 60kg   M  5.0
#
#                                                 리뷰내용  \
# 0                   처음에는 너무 오버핏이라 걱정했는데 막상 입어보니 이쁘네요
# 1                  무신사에서 좋은 가격에 잘 산거 같아요 오래 쓸 것 같습니다
# 2  생각보다 많이 얇고 주름이 잘 생기는 셔츠에여 근데 핏이 사기라 그냥 사는 걸 추천...
# 3                   엠사이즈가 딱 좋은듯해요 네이비색도 하나 살가 생각중이에오
# 4               옥스포드로 구매했어요시티보이/캐주얼로 입으려 샀는데 찰떡콩떡이네요
#
#                                           pre_review
# 0                  처음에는 너무 오버핏이라 걱정했는데 막상 입어보니 이 쁘네요
# 1                무신사에서 좋은 가격에 잘 산 거 같아 요 오래 쓸 것 같습니다
# ...

# %%
from tqdm import tqdm

# %%
from konlpy.tag import Okt

okt = Okt()

stopwords = '있어요 입니다 해서 그냥 같아요 아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 욘 고 거 오 어 이다 하다 수 듯 약간 또 고 땐 어디 신다 지다 하다 있다 오 듭니 싶다 자다 추 입 않다 더 사 어디 정말 돼 그 외 살다 로 요 왓네 귣귣 하다 없다 잘살다 자다 것 용 금메메 메 요 필 루미 트 구 만하 비엔 때 좋 궇 여서 움 전 안해 기다 거 같다 안다 때 치유 론 이면 쇼 대다 자주 나다 무 분 습 리도 야하다 니 도 첨 로나 치이다 아주 화중 재 거리 늘 겉 는걸 지게 너무 니다 쁘네 들다 상이 진짜 가다 고요 이기다 쁠듯 파파팟 걸 게 산 못 박 시해 끝 플루 미네 덕분 뻤어 읍니 기 장 시 뻐 합 흐 쩜 기용 유 산 꽤 젛 풀 입하 건 아시 빼 류 비 이군 감 단 위 쁘답니 하니 쁠듯 신 막 드네 누 테 통해 요면 해 당 꽉 라면 사도 몹시 쁘긴 진짜 뭐 뒤 살짝 가면 열 비 하니 나름 아예 자체 딲 요즘 딱 치유 론 이면 쇼 대다 자주 나다 무 분 습 리도 야하다 니 도 첨 로나 치이다 아주 화중 재 거리 늘 겉 는걸 지게'.split()

# %%
stopwords
# Out:
# ['있어요',
#  '입니다',
#  '해서',
#  '그냥',
#  '같아요',
#  '아',
#  '휴',
#  '아이구',
#  '아이쿠',
#  '아이고',
#  '어',
#  '나',
#  '우리',
#  '저희',
#  '따라',
#  '의해',
#  '을',
#  '를',
#  '에',
#  '의',
#  '가',
#  '으로',
#  '로',
#  '에게',
#  '뿐이다',
#  '의거하여',
#  '근거하여',
#  '입각하여',
#  '기준으로',
#  '예하면',
#  '예를',
#  '들면',
#  '예를',
#  '들자면',
#  '저',
#  '소인',
#  '소생',
#  '저희',
#  '지말고',
#  '하지마',
#  '하지마라',
#  '다른',
#  '물론',
#  '또한',
#  '그리고',
#  '비길수',
#  '없다',
#  '해서는',
#  '안된다',
#  '뿐만',
#  '아니라',
#  '만이',
#  '아니다',
#  '만은',
#  '아니다',
#  '막론하고',
#  '관계없이',
#  '그치지',
#  '않다',
#  '그러나',
#  '그런데',
#  '하지만',
#  '든간에',
#  '논하지',
#  '않다',
#  '따지지',
#  '않다',
#  '설사',
#  '비록',
#  '더라도',
#  '아니면',
#  '만',
#  '못하다',
#  '하는',
#  '편이',
#  '낫다',
#  '불문하고',
#  '향하여',
#  '향해서',
#  '향하다',
#  '쪽으로',
#  '틈타',
#  '이용하여',
#  '타다',
#  '오르다',
#  '제외하고',
#  '이',
#  '외에',
#  '이',
#  '밖에',
#  '하여야',
#  '비로소',
#  '한다면',
#  '몰라도',
#  '외에도',
#  '이곳',
#  '여기',
#  '부터',
#  '기점으로',
#  '따라서',
#  '할',
#  '생각이다',
#  '하려고하다',
#  '이리하여',
#  '그리하여',
# ...

# %%
nouns = []


for sent in tqdm(df['pre_review']) :
    pos = okt.pos(sent, norm = True, stem = True)
    main_words1 = [x[0] for x in pos if x[1] in ('Noun')]
    
    final_words1 = [x for x in main_words1 if not x in stopwords]

    main_words_str1 = ' '.join(final_words1)
    nouns.append(main_words_str1)

df['pos_nouns'] = nouns
# Out:
# 100%|████████████████████████████████| 827445/827445 [1:54:11<00:00, 120.77it/s]

# %%
df['제품코드'] = df['제품코드'].astype('int')
df['별점'] = df['별점'].astype('int')
df.info()

# %%
df.to_csv('review_tokenized.csv', encoding = 'utf-8')

# %%
df.head()
# Out:
#      제품코드   리뷰유형    레벨        회원아이디        리뷰날짜               회원스팩 사이즈  별점  \
# 0  994588  style  LV.5      선한주황주얼리  2023.04.14  남성 · 183cm · 73kg   L   5
# 1  994588  style  LV.6        감자여섯개  2020.06.03                NaN   M   3
# 2  994588  style   NaN          NaN  2021.02.12  여성 · 158cm · 40kg   M   5
# 3  994588  style  LV.6          고찌리  2022.07.14                NaN   M   5
# 4  994588  style  LV.5  @caesarceas  2023.06.25  남성 · 174cm · 60kg   M   5
#
#                                                 리뷰내용  \
# 0                   처음에는 너무 오버핏이라 걱정했는데 막상 입어보니 이쁘네요
# 1                  무신사에서 좋은 가격에 잘 산거 같아요 오래 쓸 것 같습니다
# 2  생각보다 많이 얇고 주름이 잘 생기는 셔츠에여 근데 핏이 사기라 그냥 사는 걸 추천...
# 3                   엠사이즈가 딱 좋은듯해요 네이비색도 하나 살가 생각중이에오
# 4               옥스포드로 구매했어요시티보이/캐주얼로 입으려 샀는데 찰떡콩떡이네요
#
#                                           pre_review               pos_nouns  \
# 0                  처음에는 너무 오버핏이라 걱정했는데 막상 입어보니 이 쁘네요            처음 오버핏 걱정 막상
# ...
